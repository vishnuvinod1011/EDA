# %% [markdown]
# # Sales Customer Interaction
# This dataset is a comprehensive record of customer transactions, designed to provide insights into sales performance, customer behavior, and product trends. It contains 20 columns, each capturing key aspects of business operations. Transaction details such as TransactionID, DateTime, and TotalAmount enable the analysis of sales trends and revenue patterns over time.
#
# Customer-related data, including CustomerID, CustomerName, Age, Gender, Country, and City, offers valuable insights into demographic and geographic influences on purchasing behavior. These fields facilitate segmentation analyses, allowing businesses to identify and target specific customer groups more effectively.
# The product dimension of the dataset includes columns such as ProductID, ProductName, Category, Price, and Quantity, enabling businesses to assess product performance and optimize inventory management. Discounts (DiscountApplied) and payment methods (PaymentMethod) further provide insights into purchasing incentives and payment preferences. Finally, customer feedback, including ReviewRating and Feedback, helps assess satisfaction levels and identify opportunities for improvement. Together, this dataset offers a robust foundation for data-driven decision-making and strategic planning.

# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_rows=1000
df=pd.read_csv(r"D:\\Data Science\\Data set\\updated_sales_customer_interaction_data.csv")

# %% [markdown]
# # Printing the first 20 rows

# %%
df.head(20)
# Out:
#    TransactionID             DateTime  CustomerID        CustomerName  Age  \
# 0        TXN1000  2023-07-03 14:41:00        9282   Christina Johnson   68
# 1        TXN1001  2023-04-29 00:52:00        5476        Joshua White   19
# 2        TXN1002  2023-06-05 14:55:00        3171       Casey Wheeler   36
# 3        TXN1003  2023-09-13 06:47:00        4931    Matthew Campbell   66
# 4        TXN1004  2023-04-26 10:15:00        5670  Christine Mitchell   31
# 5        TXN1005  2023-02-04 07:35:00        1328     Frances Frazier   48
# 6        TXN1006  2023-02-08 16:22:00        2403      Connie Johnson   28
# 7        TXN1007  2023-10-09 07:56:00        2488     Kimberly Hansen   57
# 8        TXN1008  2023-09-06 23:08:00        5278      Terri Martinez   71
# 9        TXN1009  2023-03-12 10:27:00        9437          Kelly Rose   73
# 10       TXN1010  2023-10-20 07:05:00        3392    Christopher Ross   52
# ...

# %% [markdown]
# # Printing the last 20 rows

# %%
df.tail(20)
# Out:
#     TransactionID             DateTime  CustomerID    CustomerName  Age  \
# 980       TXN1980  2023-08-16 08:55:00        6801    Timothy Hill   38
# 981       TXN1981  2023-09-30 14:17:00        2622     Rachel West   26
# 982       TXN1982  2023-08-23 06:37:00        7732    Gary Roberts   42
# 983       TXN1983  2023-09-08 02:54:00        2426    Robert Clark   44
# 984       TXN1984  2023-03-13 12:33:00        6920     Jenny Jones   47
# 985       TXN1985  2023-11-08 17:42:00        4122  Terri Castillo   62
# 986       TXN1986  2023-01-14 01:08:00        3280      James Hall   53
# 987       TXN1987  2023-05-14 22:45:00        6017      Sara Gross   54
# 988       TXN1988  2023-09-21 20:08:00        1474     Adam Butler   29
# 989       TXN1989  2023-06-07 17:45:00        1273   Jessica Walsh   56
# 990       TXN1990  2023-11-14 01:31:00        8047  Jessica Palmer   73
# 991       TXN1991  2023-08-20 13:41:00        2860      Terry Nash   53
# ...

# %% [markdown]
# # Data Cleaning

# %%
df=pd.read_csv(r"D:\\Data Science\\Data set\\updated_sales_customer_interaction_data.csv")
df.columns = [col.replace(" ", "_") for col in df.columns]
df.dropna(inplace=True)
df['DateTime']=pd.to_datetime(df['DateTime'])
numeric_column = 'numeric_column'
if numeric_column in df.columns:
    df[numeric_column].fillna(df[numeric_column].mean(), inplace=True)
categorical_column = 'categorical_column'
if categorical_column in df.columns:
    df[categorical_column].fillna('Unknown', inplace=True)
df.drop_duplicates(inplace=True)
print(df.shape)
df.isna().sum()
df.info()
# Out:
# (1000, 20)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    1000 non-null   object
#  1   DateTime         1000 non-null   datetime64[ns]
#  2   CustomerID       1000 non-null   int64
#  3   CustomerName     1000 non-null   object
#  4   Age              1000 non-null   int64
#  5   Gender           1000 non-null   object
#  6   Country          1000 non-null   object
#  7   City             1000 non-null   object
#  8   ProductID        1000 non-null   object
#  9   ProductName      1000 non-null   object
#  10  Category         1000 non-null   object
#  11  Price            1000 non-null   float64
#  12  Quantity         1000 non-null   int64
#  13  TotalAmount      1000 non-null   float64
#  14  DiscountApplied  1000 non-null   float64
#  15  PaymentMethod    1000 non-null   object
# ...

# %% [markdown]
# ### Checking for any duplicates

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# # Statistical Analysis

# %%
numeric_data = df.select_dtypes(include=['float64', 'int64'])
stat_an=numeric_data.describe()
print(stat_an)
print(df.head(20))
print(df.tail())
plt.figure(figsize=(15, 10))
sns.boxplot(data=numeric_data)
plt.title('Boxplot of Numeric Data')
plt.xticks(rotation=90)
plt.show()
# Out:
#         CustomerID          Age        Price     Quantity  TotalAmount  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean   5552.018000    46.543000   253.474590     5.539000  1286.503750
# std    2580.000232    16.432047   139.903907     2.907737  1090.999189
# min    1000.000000    18.000000     5.750000     1.000000    10.200000
# 25%    3371.500000    32.750000   134.505000     3.000000   398.075000
# 50%    5550.500000    46.000000   258.385000     6.000000   958.205000
# 75%    7748.750000    60.000000   371.732500     8.000000  1909.187500
# max    9999.000000    75.000000   499.600000    10.000000  4828.000000
#
#        DiscountApplied  ReviewRating
# count      1000.000000   1000.000000
# mean        137.256740      2.968300
# std         152.605452      1.189395
# min           0.040000      1.000000
# 25%          27.140000      1.900000
# 50%          80.925000      3.000000
# 75%         192.942500      4.000000
# ...

# %% [markdown]
# # Performing Correlation

# %% [markdown]
# # Performing Covariance

# %%
covarience=numeric_data.cov()
print(covarience)
plt.figure(figsize=(12,8))
sns.heatmap(covarience,cmap='rainbow',annot=True,fmt='.2f',linewidths=0.5)
plt.title("covarience")
plt.show()
# Out:
#                    CustomerID         Age          Price     Quantity  \
# CustomerID       6.656401e+06  822.645872   22106.081118  -226.884587
# Age              8.226459e+02  270.012163     -22.679472     0.510834
# Price            2.210608e+04  -22.679472   19573.103281    19.784521
# Quantity        -2.268846e+02    0.510834      19.784521     8.454934
# TotalAmount      6.809936e+04  -84.375061  105435.587149  2090.030790
# DiscountApplied  1.335798e+04  -78.320430   10672.477748   217.643120
# ReviewRating    -1.372626e+01    0.538552       3.081399    -0.201916
#
#                   TotalAmount  DiscountApplied  ReviewRating
# CustomerID       6.809936e+04     13357.982231    -13.726256
# Age             -8.437506e+01       -78.320430      0.538552
# Price            1.054356e+05     10672.477748      3.081399
# Quantity         2.090031e+03       217.643120     -0.201916
# TotalAmount      1.190279e+06    107612.136636    -35.835107
# ...

# %% [markdown]
# # 1. What is the total revenue generated across all sales?

# %%
total_revenue = df['TotalAmount'].sum()
print(f"Total Revenue: {total_revenue}")
# Out:
# Total Revenue: 1286503.75

# %% [markdown]
# # 2. Which product or service category has the highest sales volume?

# %%
category_sales = df.groupby('Category')['TotalAmount'].sum()
top_category = category_sales.idxmax()
top_category_sales = category_sales.max()

print(f"The category with the highest sales volume is '{top_category}' with total sales of {top_category_sales}.")
# Out:
# The category with the highest sales volume is 'Electronics' with total sales of 256776.84.

# %% [markdown]
# # 3. Which region or location contributed the most to overall sales?

# %%
country_sales = df.groupby('Country')['TotalAmount'].sum()
top_country = country_sales.idxmax()
top_country_sales = country_sales.max()

print(f"The country contributing the most to overall sales is '{top_country}' with total sales of {top_country_sales}.")
# Out:
# The country contributing the most to overall sales is 'Barbados' with total sales of 17279.28.

# %% [markdown]
# # 4. What percentage of total sales comes from repeat customers?

# %%
repeat_customers = df[df.duplicated('CustomerID', keep=False)]
repeat_sales = repeat_customers['TotalAmount'].sum()
percentage_repeat_sales = (repeat_sales / total_revenue) * 100
print(f"Percentage of total sales from repeat customers: {percentage_repeat_sales:.2f}%")
# Out:
# Percentage of total sales from repeat customers: 9.32%

# %% [markdown]
# # 5. Which customer demographic group contributes the highest revenue?

# %%
gender_sales = df.groupby('Gender')['TotalAmount'].sum()
top_gender = gender_sales.idxmax()
top_gender_sales = gender_sales.max()

print(f"The gender contributing the most to overall sales is '{top_gender}' with total sales of {top_gender_sales}.")
# Out:
# The gender contributing the most to overall sales is 'Male' with total sales of 454450.45.

# %% [markdown]
# # 6. What is the average transaction value across different customer segments?

# %%
avg_transaction_value_gender = df.groupby('Gender')['TotalAmount'].mean()
print("Average Transaction Value by Gender:")
print(avg_transaction_value_gender)
# Out:
# Average Transaction Value by Gender:
# Gender
# Female    1249.916172
# Male      1336.618971
# Other     1271.924303
# Name: TotalAmount, dtype: float64

# %% [markdown]
# # 7. How many unique customers are in the dataset?

# %%
unique_customers = df['CustomerID'].nunique()
print(f"Unique Customers: {unique_customers}")
# Out:
# Unique Customers: 953

# %% [markdown]
# # 8. Which day of the week shows the highest level of customer interactions?

# %%
df['DateTime'] = pd.to_datetime(df['DateTime'])
df['DayOfWeek'] = df['DateTime'].dt.day_name()


interactions_per_day = df['DayOfWeek'].value_counts()
top_day_of_week = interactions_per_day.idxmax()

print(f"The day of the week with the highest customer interactions is {top_day_of_week}.")
# Out:
# The day of the week with the highest customer interactions is Monday.

# %% [markdown]
# # 9. What is the average number of interactions per sale?

# %%
avg_interactions_per_sale = df['ReviewRating'].count() / len(df)
print(f"Average number of interactions per sale: {avg_interactions_per_sale:.2f}")
# Out:
# Average number of interactions per sale: 1.00

# %% [markdown]
# # 10. How does the number of customer interactions correlate with sales outcomes?

# %%
correlation = df['ReviewRating'].corr(df['TotalAmount'])
print(f"Correlation between customer interactions and sales: {correlation:.2f}")
# Out:
# Correlation between customer interactions and sales: -0.03

# %% [markdown]
# # 11. Are there seasonal trends in sales or customer engagement levels?

# %%
df['Month'] = df['DateTime'].dt.month
monthly_sales = df.groupby('Month')['TotalAmount'].sum()
print("Seasonal Trends in Sales (Monthly):")
print(monthly_sales)
# Out:
# Seasonal Trends in Sales (Monthly):
# Month
# 1     122218.33
# 2      98597.52
# 3      93341.45
# 4     108929.64
# 5     131247.51
# 6      96103.20
# 7      92824.29
# 8     124748.64
# 9     113370.55
# 10    111244.46
# 11    110430.48
# 12     83447.68
# Name: TotalAmount, dtype: float64

# %% [markdown]
# # 12. Which product or service benefits most from high customer interaction levels?

# %%
product_interaction_correlation = df.groupby('ProductName')['ReviewRating'].mean()
top_product = product_interaction_correlation.idxmax()
print(f"The product benefiting most from high customer interactions is '{top_product}'.")
# Out:
# The product benefiting most from high customer interactions is 'Yoga Mat'.

# %% [markdown]
# # 13. Which regions or territories generate the most revenue?

# %%
import pandas as pd
import matplotlib.pyplot as plt


file_path = ('D:\\Data Science\\Data set\\updated_sales_customer_interaction_data.csv')
data = pd.read_csv(file_path)


region_revenue = data.groupby('Country')['TotalAmount'].sum().sort_values(ascending=False)


plt.figure(figsize=(12, 6))
region_revenue.plot(kind='line', color='coral')
plt.title('Revenue by Region')
plt.xlabel('Region (Country)')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Display summarized revenue
print(region_revenue)
# Out:
# Country
# Barbados                                               17279.28
# Ukraine                                                16999.95
# Greenland                                              15619.67
# Haiti                                                  14185.14
# Oman                                                   13012.18
# Poland                                                 11939.41
# Mozambique                                             11922.47
# Western Sahara                                         11802.97
# Namibia                                                11739.03
# Seychelles                                             11600.73
# Libyan Arab Jamahiriya                                 11581.34
# Christmas Island                                       11560.61
# Antarctica (the territory South of 60 deg S)           11537.40
# Bermuda                                                11379.22
# Lesotho                                                11246.70
# ...

# %% [markdown]
# # 14. What is the trend in customer acquisition over time?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = ('D:\\Data Science\\Data set\\updated_sales_customer_interaction_data.csv')
data = pd.read_csv(file_path)

# Convert DateTime column to datetime format
data['DateTime'] = pd.to_datetime(data['DateTime'])

# Extract the date for aggregation (you can also use months or years for granularity)
data['Date'] = data['DateTime'].dt.date

# Identify unique customers per date
customer_trend = data.groupby('Date')['CustomerID'].nunique()

# Plot the trend
plt.figure(figsize=(12, 6))
customer_trend.plot(kind='line', marker='o', color='green')
plt.title('Trend in Customer Acquisition Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Unique Customers')
plt.grid()
plt.tight_layout()
plt.show()

# Display the trend data
print(customer_trend)
# Out:
# Date
# 2023-01-01    2
# 2023-01-02    2
# 2023-01-03    2
# 2023-01-04    1
# 2023-01-05    2
# 2023-01-06    6
# 2023-01-07    4
# 2023-01-08    1
# 2023-01-09    5
# 2023-01-10    3
# 2023-01-11    4
# 2023-01-12    1
# 2023-01-13    2
# 2023-01-14    4
# 2023-01-15    2
# 2023-01-16    5
# 2023-01-17    3
# 2023-01-18    1
# 2023-01-19    6
# 2023-01-20    1
# 2023-01-21    4
# 2023-01-22    4
# 2023-01-23    3
# 2023-01-24    2
# 2023-01-25    1
# 2023-01-26    3
# 2023-01-27    2
# 2023-01-28    6
# 2023-01-29    5
# 2023-01-30    3
# 2023-01-31    1
# 2023-02-01    3
# 2023-02-02    2
# 2023-02-03    2
# 2023-02-04    3
# 2023-02-05    1
# 2023-02-06    3
# 2023-02-07    2
# 2023-02-08    5
# 2023-02-09    4
# 2023-02-10    3
# 2023-02-11    2
# 2023-02-12    1
# 2023-02-13    6
# 2023-02-14    4
# 2023-02-15    2
# 2023-02-16    2
# 2023-02-17    4
# 2023-02-18    5
# 2023-02-19    3
# 2023-02-20    4
# 2023-02-22    1
# 2023-02-23    2
# 2023-02-24    2
# 2023-02-25    3
# ...

# %% [markdown]
# # 15. How does sales performance vary by day of the week or time of day?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = ('D:\\Data Science\\Data set\\updated_sales_customer_interaction_data.csv')
data = pd.read_csv(file_path)

# Convert DateTime column to datetime format
data['DateTime'] = pd.to_datetime(data['DateTime'])

# Extract day of the week and hour of the day
data['DayOfWeek'] = data['DateTime'].dt.day_name()
data['HourOfDay'] = data['DateTime'].dt.hour

# Sales performance by day of the week
sales_by_day = data.groupby('DayOfWeek')['TotalAmount'].sum().reindex(
    ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
)

# Sales performance by hour of the day
sales_by_hour = data.groupby('HourOfDay')['TotalAmount'].sum()

# Plot sales by day of the week
plt.figure(figsize=(12, 6))
sales_by_day.plot(kind='bar', color='skyblue')
plt.title('Sales Performance by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot sales by hour of the day
plt.figure(figsize=(12, 6))
sales_by_hour.plot(kind='line', marker='o', color='orange')
plt.title('Sales Performance by Hour of the Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Total Sales')
plt.grid()
plt.tight_layout()
plt.show()

# Display summarized data
print("Sales by Day of the Week:")
print(sales_by_day)
print("\nSales by Hour of the Day:")
print(sales_by_hour)
# Out:
# Sales by Day of the Week:
# DayOfWeek
# Monday       230125.16
# Tuesday      155651.28
# Wednesday    181992.93
# Thursday     171308.36
# Friday       164561.12
# Saturday     197290.85
# Sunday       185574.05
# Name: TotalAmount, dtype: float64
#
# Sales by Hour of the Day:
# HourOfDay
# 0     51522.62
# 1     51890.70
# 2     37624.07
# 3     73097.63
# 4     52682.58
# 5     55318.58
# 6     43039.95
# 7     53533.18
# 8     57532.20
# 9     56328.38
# 10    39485.43
# 11    49857.46
# 12    56641.84
# 13    61476.51
# 14    53659.69
# 15    54834.68
# 16    62340.09
# 17    58143.44
# 18    46159.25
# 19    46407.68
# 20    67487.84
# 21    55345.73
# 22    35717.84
# 23    66376.38
# Name: TotalAmount, dtype: float64

# %% [markdown]
# # 16. What is the distribution of sales values?

# %%
import matplotlib.pyplot as plt
# Plot the histogram of TotalAmount
if 'TotalAmount' in df.columns:
    plt.figure(figsize=(10, 6))
    plt.hist(df['TotalAmount'], bins=20, color='skyblue', edgecolor='black')
    plt.title('Distribution of Sales Values (TotalAmount)', fontsize=16)
    plt.xlabel('Sales Value (TotalAmount)', fontsize=14)
    plt.ylabel('Frequency', fontsize=14)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()
else:
    print("The dataset does not contain a 'TotalAmount' column.")

# %% [markdown]
# # 17. How does the volume of customer interactions vary across months and weekdays?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
file_path = ('D:\\Data Science\\Data set\\updated_sales_customer_interaction_data.csv')
df = pd.read_csv(file_path)

# Ensure the DateTime column is in the correct format
df['DateTime'] = pd.to_datetime(df['DateTime'])

# Extract the month and weekday
df['month'] = df['DateTime'].dt.month_name()
df['weekday'] = df['DateTime'].dt.day_name()

# Group by month and weekday, then count the number of interactions
heatmap_data = df.groupby(['month', 'weekday']).size().unstack()

# Reorder the weekdays for better visualization
weekday_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
heatmap_data = heatmap_data.reindex(columns=weekday_order)

# Plot the heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, fmt=".0f", cbar_kws={'label': 'Number of Interactions'})
plt.title('Customer Interactions by Month and Weekday')
plt.ylabel('Month')
plt.xlabel('Weekday')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 18. What is the correlation between sales figures, interaction frequency, and product categories?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
file_path = ('D:\\Data Science\\Data set\\updated_sales_customer_interaction_data.csv')
df = pd.read_csv(file_path)

# Ensure the DateTime column is in the correct format
df['DateTime'] = pd.to_datetime(df['DateTime'])

# Aggregate data to calculate sales, interaction frequency, and group by product categories
category_summary = df.groupby('Category').agg(
    total_sales=('TotalAmount', 'sum'),
    interaction_count=('TransactionID', 'count'),
    avg_sales=('TotalAmount', 'mean')  # Example metric for additional insight
).reset_index()

# Calculate the correlation matrix
correlation_matrix = category_summary[['total_sales', 'interaction_count', 'avg_sales']].corr()

# Plot the heatmap for the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", cbar_kws={'label': 'Correlation Coefficient'})
plt.title('Correlation Between Sales Figures, Interaction Frequency, and Product Categories')
plt.show()

# %% [markdown]
# # Summary
# ### This project focuses on analyzing a comprehensive dataset of customer transactions to gain insights into sales performance, customer behavior, and product trends. The dataset includes various details such as transaction IDs, customer demographics, product information, sales figures, and customer feedback. Key analyses conducted include tracking changes in sales over time, identifying the products and services generating the most revenue, and exploring how customer interactions vary by month and weekday. These analyses help uncover seasonal trends and patterns that can inform strategic decisions
#
# ### A significant portion of the analysis was dedicated to understanding customer behavior. This included determining the number of unique customers in the dataset, calculating the average number of interactions per customer, and identifying customers with higher or lower interaction frequencies. The relationship between customer demographics (e.g., age, gender, country) and their purchasing decisions was also explored. This allowed for a deeper understanding of how different customer segments engage with the products and how geography influences sales.
#
# ### The project also included a focus on product and sales performance, where correlations between sales figures, interaction frequencies, and product categories were analyzed. Insights into how geographic factors, such as country and city, affect sales were explored. Additionally, customer feedback trends were studied by analyzing review ratings and correlating them with product categories and individual products. This analysis helped identify areas for product improvement and assess customer satisfaction, contributing to future strategies for enhancing sales and customer experience.

# %% [markdown]
# # Conclusion
# ### In conclusion, this project successfully analyzed a dataset of customer transactions to gain valuable insights into sales trends, customer behavior, and product performance. By examining changes in sales over time, identifying top-performing products, and understanding how interactions vary by month and weekday, the project provided a deeper understanding of purchasing patterns. Customer behavior was further explored by analyzing demographics, interaction frequencies, and engagement levels, revealing key segments that influence sales. Additionally, correlations between sales figures, product categories, and customer feedback highlighted areas for improvement and growth. Overall, the findings offer actionable insights to optimize sales strategies, enhance customer experiences, and inform business decisions moving forward.
